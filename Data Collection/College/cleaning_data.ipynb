# %%
import pandas as pd

# %%
# Starting with 2015 batting leaders        

# Setting up the inital data frame
main_db = pd.read_csv("Scraped Data/college_batting_leaders_2015.csv")

# %%
# Setting up feature set 

print(main_db.columns)

features = main_db.columns
# Out:
# Index(['Age', 'Tm', 'Lg', 'Lev', 'BA', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B',
#        'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'OBP', 'SLG', 'OPS', 'TB', 'GDP',
#        'HBP', 'SH', 'SF', 'IBB'],
#       dtype='object')

# %%
main_db = main_db.drop(columns=['Name', 'Aff'])

# %%
main_db.head(5)
# Out:
#   Age   Tm    Lg   Lev     BA   G   PA   AB   R    H  ...  SO    OBP    SLG  \
# 0  --  UCH   UAA  NCAA  0.486  38  166  140  36   68  ...  13  0.545  0.750
# 1  20  UNY  LIBL  NCAA  0.477  36  130  111  26   53  ...  15  0.543  0.559
# 2  21  CTW   SAC  NCAA  0.467  62  286  244  75  114  ...  21  0.531  0.865
# 3  23  UEV   MVC  NCAA  0.465  46  221  185  43   86  ...  23  0.543  0.746
# 4  --  SVC  PRES  NCAA  0.464  35  130  110  21   51  ...   8  0.512  0.573
#
#      OPS   TB  GDP  HBP  SH  SF  IBB
# 0  1.295  105  NaN    8   1   3    1
# 1  1.101   62  NaN    0   1   1    2
# 2  1.396  211  NaN   12   0   4    7
# 3  1.289  138  NaN    6   0   2    4
# 4  1.085   63  NaN    3   5   2    0
#
# [5 rows x 27 columns]
